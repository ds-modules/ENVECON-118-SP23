# %% [markdown]
# ### Indicate the Following:

# %% [markdown]
# Name:
#
# SID:
#
# GSI: (Sara or Seung)

# %% [markdown]
# # Midterm 2023 - EEP/IAS 118 - Villas Boas

# %% [markdown]
# **Instructions:** Please answer questions in the boxes and spaces provided. This is an open book midterm. You must solve the exam alone. Any cooperation will be penalized with a 0 in this midterm.
#
# To receive credit:
# 1. Show your work. e.g., In interpreting the regression coefficient of X on Y, via our SSS framework, if you determine that there is statistical significance at 1% significance level, demonstrate how you came to such conclusion.
# 2. *Do not* round your answer or intermediate steps to less than four decimal digits
# 3. Be sure all writing is visible and legible on the scanned pdf
# 4. Submit to Gradescope as one pdf; Assign all and only the appropriate pages to each question
#
# This exam **does not require R**. R may be used as a calculator or to obtain critical values from statistical tables, but no credit will be given for the use of confidence interval or hypothesis test functions. If R is used to complete steps on a problem, make sure to include the utilized code. (For hand written exam, if you are finding critical values by R or table, either write down the R code or give us all the necessary ingredients for finding it, such as distribution assumed, alpha or alpha/2, and/or degrees of freedom.) **Final answers must be placed in the appropriate text/Markdown cell** - text/comments in coding cells will not be graded. **70 Points Total**

# %% [markdown]
# ### Question 1 (Total: 10 Points)

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.54.53 PM.png](attachment:d67d0893-1f91-4c4a-9c99-48c3e4570e3d.png)

# %%
# Include any code used for Q1 here only. (Coding Cell) Final answers do not belong in this cell.

# %% [markdown]
# ➡️ **Write Solution Here:**
# - $\hat{p}$ =
#
# - SE of $\hat{p}$ =
#
# - Confidence level is:
#     1) 99%
#     2) 95%
#     3) 90%

# %% [markdown]
# ➡️ Show your work here. Round answers to four decimal digits. (Markdown Cell)

# %% [markdown]
# ### Question 2 (Total: 30 Points)

# %% [markdown]
# In question 2, we employ a dataset that records the following variables for each of the 51 states in January 2023:
#
# |Variable| Variable Description (Units)    |
# |-----------|---------------|
# | regularPrice (regular) | Price of regular gasoline in the state (USD)|
# | winteroxygenregul | Indicator variable for whether the state has winter environmental regulation|
# |  | = 1, if state has winter environmental regulation|
# |  | = 0, otherwise|
# | CarsPc (pccars) | Number of cars per capita in the state|
# | Percentleanrep2022 | Percent of population leaning republican in the state (%)|

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.06.03 PM.png](attachment:e9e3f98b-bb92-4e96-a8c6-6c57e0925c14.png)
#
# ![Screenshot 2023-03-14 at 9.56.22 PM.png](attachment:465a5b21-fa56-48b1-a854-f26617cae8c0.png)
#
# ![Screenshot 2023-03-14 at 9.06.26 PM.png](attachment:b08cd864-6db4-40d2-a584-9583b1ee7132.png)

# %%
# Include any code used for Q2-(a) here. (Coding Cell) Final answers do not belong in this cell.

# %% [markdown]
# ➡️ Type your answer / steps for Q2-(a) here. (Markdown Cell)

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.05.34 PM.png](attachment:b9421b0c-fcac-46ad-bde3-92d617fad190.png)
#
# ![Screenshot 2023-03-14 at 9.05.06 PM.png](attachment:2c7763df-3ebf-41c6-b254-efb916a93ce5.png)
#
# Give the shortest answer being as correct and complete as possible.
#
# YES, because... *or* NO, because...

# %% [markdown]
# ➡️ Type your answer / steps for Q2-(b) here. (Markdown Cell)

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.03.56 PM.png](attachment:3ff8fbb6-21fc-44cb-8fb3-3d1cbfadb5f6.png)
#
# ![Screenshot 2023-03-12 at 10.11.35 PM.png](attachment:cfb774d2-d6a5-415e-afce-3e82a90a0e9c.png)
#
# ![Screenshot 2023-03-12 at 10.11.59 PM.png](attachment:3e9ac9de-282c-4241-a346-64a64ef32208.png)

# %% [markdown]
# ➡️ Type your answer / steps for Q2-(c) here. (Markdown Cell)

# %%
# Include any code used for Q2-(c) here. (Coding Cell) Final answers do not belong in this cell.

# %% [markdown]
# ### Question 3 (Total: 30 Points)

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.03.35 PM.png](attachment:9cee062e-60da-417a-aa9f-5865c962cac1.png)
#
# ![Screenshot 2023-03-12 at 10.13.54 PM.png](attachment:bedb649c-6c5b-43f2-9f60-172d6e7c5f4e.png)

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.03.08 PM.png](attachment:de8ae1ad-3d93-43ef-a63d-f82591f5c7b6.png)

# %% [markdown]
# ➡️ Type your answer / steps for Q3-(a) here. (Markdown Cell)

# %%
# Include any code used for Q3-(a) here. (Coding Cell) Final answers do not belong in this cell.

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.02.36 PM.png](attachment:7d76f436-8c1e-4f09-9cbf-7b55da04a647.png)

# %% [markdown]
# ➡️ Type your answer / steps for Q3-(b) here. (Markdown Cell)

# %%
# Include any code used for Q3-(b) here. (Coding Cell) Final answers do not belong in this cell.

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.02.09 PM.png](attachment:c277caad-600d-4f62-9c6a-9ed8b9779d28.png)

# %% [markdown]
# ➡️ Type your answer / steps for Q3-(c) here. (Markdown Cell)

# %%
# Include any code used for Q3-(c) here. (Coding Cell) Final answers do not belong in this cell.

# %% [markdown]
# ![Screenshot 2023-03-14 at 9.01.34 PM.png](attachment:15ac6b0d-ed41-4a02-827f-7981f3c9ac6e.png)

# %% [markdown]
# ➡️ Type your answer / steps for Q3-(d) here. (Markdown Cell)

# %%
# Include any code used for Q3-(d) here. (Coding Cell) Final answers do not belong in this cell.
